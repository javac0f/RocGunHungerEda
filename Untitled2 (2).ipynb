# %%
import pandas as pd
# BASIC DS LIBS
import openpyxl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# FILE IO LIBS
import os 
from os.path import join 

# GEOSPATIAL LIBS
from osgeo import gdal
import geopandas as gpd
from geopandas import GeoDataFrame

# PLOT LIBS
import plotly.express as px 
import plotly.graph_objects as go
from shapely.geometry import Point
from plotly.subplots import make_subplots
gun_data = pd.read_csv('Rochester_NY_Shooting_Victims.csv')

# %%
from geopy.geocoders import Nominatim

# %%
gun_2022 = gun_data[gun_data["Occurred_Year"] == 2022]

# %%
t = gun_2022["Occurred_Year"] == 2022

# %%
t.unique()
# Out:
# array([ True])

# %%
gun_2023 = gun_data[gun_data["Occurred_Year"] == 2023]

# %%
gun_2023
# Out:
# Empty DataFrame
# Columns: [X, Y, ID, Case_Number, Address, Occurred_Date, Occurred_Month, Occurred_Year, Crime_Type, Multiple_Shooting, Gender, Race, Ethnicity, Victim_Age, Victim_Age_Band, Latitude, Longitude, ObjectId]
# Index: []

# %%
gun_2022
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.610890  43.184163  7b9b3c9f85a442ce6a0aa2433ab8614f   22-109240
# 1   -77.598893  43.181793  82e3549d4dc8a835dea7130df2dcc851   22-106950
# 2   -77.630378  43.142970  bb9b98f90af42194e3a5b12a1ba8405f   22-106780
# 3   -77.580628  43.167216  dd0ab9214578b6e0d35467f6bb7b0fc3   22-106380
# 4   -77.641972  43.162394  5aac53d1517de031545f178e919c35b8   22-104298
# ..         ...        ...                               ...         ...
# 432 -77.594208  43.176265  170cc2716dcda68d990e13f160eb8e6d   22-002983
# 433 -77.653647  43.145521  8413049a1673e7652bc9a496b9822f8b   22-002302
# 434 -77.632012  43.160080  1cb272c96a18d27465d921e5df6df93a   22-002409
# 435 -77.603917  43.159877  11e489af1ae332d6ea0af7061c782115   22-001016
# 436 -77.626821  43.141037  1870a76a0d379ac9e58736f51974dbaf   22-000125
#
#               Address           Occurred_Date  Occurred_Month  Occurred_Year  \
# 0    442 Remington St  2022/06/01 04:00:00+00               6           2022
# 1      904 Hudson Ave  2022/05/29 04:00:00+00               5           2022
# 2     168 Bartlett St  2022/05/29 04:00:00+00               5           2022
# 3    720 N Goodman St  2022/05/28 04:00:00+00               5           2022
# 4       138 Murray St  2022/05/26 04:00:00+00               5           2022
# ..                ...                     ...             ...            ...
# 432   367 Alphonse St  2022/01/05 05:00:00+00               1           2022
# 433      211 Depew St  2022/01/04 05:00:00+00               1           2022
# 434     290 Saxton St  2022/01/04 05:00:00+00               1           2022
# 435      125 North St  2022/01/02 05:00:00+00               1           2022
# 436     204 Hawley St  2022/01/01 05:00:00+00               1           2022
#
#     Crime_Type Multiple_Shooting Gender   Race     Ethnicity  Victim_Age  \
# 0     Shooting                No      M  WHITE      HISPANIC          34
# 1     Homicide                No      M  WHITE      HISPANIC          42
# 2     Shooting                No      M  BLACK  NON HISPANIC          60
# 3     Shooting                No      M  BLACK  NON HISPANIC          28
# 4     Shooting                No      M  WHITE      HISPANIC          15
# ..         ...               ...    ...    ...           ...         ...
# 432   Shooting                No      M  BLACK  NON HISPANIC          45
# 433   Shooting                No      M  BLACK  NON HISPANIC          43
# 434   Shooting                No      M  BLACK  NON HISPANIC          15
# 435   Homicide                No      M  BLACK  NON HISPANIC          14
# 436   Shooting                No      M  BLACK  NON HISPANIC          30
#
#     Victim_Age_Band   Latitude  Longitude  ObjectId
# 0             25-44  43.184163 -77.610890         1
# 1             25-44  43.181793 -77.598893         2
# 2          45-Older  43.142970 -77.630378         3
# 3             25-44  43.167216 -77.580628         4
# 4             15-24  43.162394 -77.641972         5
# ..              ...        ...        ...       ...
# 432        45-Older  43.176265 -77.594208       433
# 433           25-44  43.145521 -77.653647       434
# 434           15-24  43.160080 -77.632012       435
# 435          14-May  43.159877 -77.603917       436
# 436           25-44  43.141037 -77.626821       437
#
# [137 rows x 18 columns]

# %%
gun_2022_23 =  pd.concat([gun_2022, gun_2023])

# %%
gun_2022_23
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.610890  43.184163  7b9b3c9f85a442ce6a0aa2433ab8614f   22-109240
# 1   -77.598893  43.181793  82e3549d4dc8a835dea7130df2dcc851   22-106950
# 2   -77.630378  43.142970  bb9b98f90af42194e3a5b12a1ba8405f   22-106780
# 3   -77.580628  43.167216  dd0ab9214578b6e0d35467f6bb7b0fc3   22-106380
# 4   -77.641972  43.162394  5aac53d1517de031545f178e919c35b8   22-104298
# ..         ...        ...                               ...         ...
# 432 -77.594208  43.176265  170cc2716dcda68d990e13f160eb8e6d   22-002983
# 433 -77.653647  43.145521  8413049a1673e7652bc9a496b9822f8b   22-002302
# 434 -77.632012  43.160080  1cb272c96a18d27465d921e5df6df93a   22-002409
# 435 -77.603917  43.159877  11e489af1ae332d6ea0af7061c782115   22-001016
# 436 -77.626821  43.141037  1870a76a0d379ac9e58736f51974dbaf   22-000125
#
#               Address           Occurred_Date  Occurred_Month  Occurred_Year  \
# 0    442 Remington St  2022/06/01 04:00:00+00               6           2022
# 1      904 Hudson Ave  2022/05/29 04:00:00+00               5           2022
# 2     168 Bartlett St  2022/05/29 04:00:00+00               5           2022
# 3    720 N Goodman St  2022/05/28 04:00:00+00               5           2022
# 4       138 Murray St  2022/05/26 04:00:00+00               5           2022
# ..                ...                     ...             ...            ...
# 432   367 Alphonse St  2022/01/05 05:00:00+00               1           2022
# 433      211 Depew St  2022/01/04 05:00:00+00               1           2022
# 434     290 Saxton St  2022/01/04 05:00:00+00               1           2022
# 435      125 North St  2022/01/02 05:00:00+00               1           2022
# 436     204 Hawley St  2022/01/01 05:00:00+00               1           2022
#
#     Crime_Type Multiple_Shooting Gender   Race     Ethnicity  Victim_Age  \
# 0     Shooting                No      M  WHITE      HISPANIC          34
# 1     Homicide                No      M  WHITE      HISPANIC          42
# 2     Shooting                No      M  BLACK  NON HISPANIC          60
# 3     Shooting                No      M  BLACK  NON HISPANIC          28
# 4     Shooting                No      M  WHITE      HISPANIC          15
# ..         ...               ...    ...    ...           ...         ...
# 432   Shooting                No      M  BLACK  NON HISPANIC          45
# 433   Shooting                No      M  BLACK  NON HISPANIC          43
# 434   Shooting                No      M  BLACK  NON HISPANIC          15
# 435   Homicide                No      M  BLACK  NON HISPANIC          14
# 436   Shooting                No      M  BLACK  NON HISPANIC          30
#
#     Victim_Age_Band   Latitude  Longitude  ObjectId
# 0             25-44  43.184163 -77.610890         1
# 1             25-44  43.181793 -77.598893         2
# 2          45-Older  43.142970 -77.630378         3
# 3             25-44  43.167216 -77.580628         4
# 4             15-24  43.162394 -77.641972         5
# ..              ...        ...        ...       ...
# 432        45-Older  43.176265 -77.594208       433
# 433           25-44  43.145521 -77.653647       434
# 434           15-24  43.160080 -77.632012       435
# 435          14-May  43.159877 -77.603917       436
# 436           25-44  43.141037 -77.626821       437
#
# [137 rows x 18 columns]

# %%
gun_long=gun_2022_23["Longitude"]

# %%
gun_lat = gun_2022_23["Latitude"]

# %%
gun_lat = gun_lat.tolist()

# %%
gun_long = gun_long.tolist()

# %%
zipcode=[]

# %%
geolocator = Nominatim(user_agent='myapplication')

# %%
for i in range(len(gun_lat)):
    location = geolocator.reverse((gun_lat[i],gun_long[i]),timeout=10)
    address = location.raw['address']
    zipcode.append(address.get('postcode'))

# %%
len(zipcode)
# Out:
# 137

# %%
gun_2022_23 = gun_2022_23.reset_index(drop=True)

# %%
gun_2022_23
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.610890  43.184163  7b9b3c9f85a442ce6a0aa2433ab8614f   22-109240
# 1   -77.598893  43.181793  82e3549d4dc8a835dea7130df2dcc851   22-106950
# 2   -77.630378  43.142970  bb9b98f90af42194e3a5b12a1ba8405f   22-106780
# 3   -77.580628  43.167216  dd0ab9214578b6e0d35467f6bb7b0fc3   22-106380
# 4   -77.641972  43.162394  5aac53d1517de031545f178e919c35b8   22-104298
# ..         ...        ...                               ...         ...
# 132 -77.594208  43.176265  170cc2716dcda68d990e13f160eb8e6d   22-002983
# 133 -77.653647  43.145521  8413049a1673e7652bc9a496b9822f8b   22-002302
# 134 -77.632012  43.160080  1cb272c96a18d27465d921e5df6df93a   22-002409
# 135 -77.603917  43.159877  11e489af1ae332d6ea0af7061c782115   22-001016
# 136 -77.626821  43.141037  1870a76a0d379ac9e58736f51974dbaf   22-000125
#
#               Address           Occurred_Date  Occurred_Month  Occurred_Year  \
# 0    442 Remington St  2022/06/01 04:00:00+00               6           2022
# 1      904 Hudson Ave  2022/05/29 04:00:00+00               5           2022
# 2     168 Bartlett St  2022/05/29 04:00:00+00               5           2022
# 3    720 N Goodman St  2022/05/28 04:00:00+00               5           2022
# 4       138 Murray St  2022/05/26 04:00:00+00               5           2022
# ..                ...                     ...             ...            ...
# 132   367 Alphonse St  2022/01/05 05:00:00+00               1           2022
# 133      211 Depew St  2022/01/04 05:00:00+00               1           2022
# 134     290 Saxton St  2022/01/04 05:00:00+00               1           2022
# 135      125 North St  2022/01/02 05:00:00+00               1           2022
# 136     204 Hawley St  2022/01/01 05:00:00+00               1           2022
#
#     Crime_Type Multiple_Shooting Gender   Race     Ethnicity  Victim_Age  \
# 0     Shooting                No      M  WHITE      HISPANIC          34
# 1     Homicide                No      M  WHITE      HISPANIC          42
# 2     Shooting                No      M  BLACK  NON HISPANIC          60
# 3     Shooting                No      M  BLACK  NON HISPANIC          28
# 4     Shooting                No      M  WHITE      HISPANIC          15
# ..         ...               ...    ...    ...           ...         ...
# 132   Shooting                No      M  BLACK  NON HISPANIC          45
# 133   Shooting                No      M  BLACK  NON HISPANIC          43
# 134   Shooting                No      M  BLACK  NON HISPANIC          15
# 135   Homicide                No      M  BLACK  NON HISPANIC          14
# 136   Shooting                No      M  BLACK  NON HISPANIC          30
#
#     Victim_Age_Band   Latitude  Longitude  ObjectId Zip_code
# 0             25-44  43.184163 -77.610890         1    14621
# 1             25-44  43.181793 -77.598893         2    14611
# 2          45-Older  43.142970 -77.630378         3    14609
# 3             25-44  43.167216 -77.580628         4    14606
# 4             15-24  43.162394 -77.641972         5    14611
# ..              ...        ...        ...       ...      ...
# 132        45-Older  43.176265 -77.594208       433    14611
# 133           25-44  43.145521 -77.653647       434    14606
# 134           15-24  43.160080 -77.632012       435    14604
# 135          14-May  43.159877 -77.603917       436    14608
# 136           25-44  43.141037 -77.626821       437      NaN
#
# [137 rows x 19 columns]

# %%
zipcode_2022_23 = pd.Series(zipcode)

gun_2022_23['Zip_code'] = zipcode_2022_23

# %%
zipcode_2022_23
# Out:
# 0      14621
# 1      14621
# 2      14611
# 3      14609
# 4      14606
#        ...
# 132    14621
# 133    14611
# 134    14606
# 135    14604
# 136    14608
# Length: 137, dtype: object

# %%
zipcode
# Out:
# ['14621',
#  '14621',
#  '14611',
#  '14609',
#  '14606',
#  '14611',
#  '14609',
#  '14609',
#  '14619',
#  '14609',
#  '14621',
#  '14613',
#  '14609',
#  '14621',
#  '14608',
#  '14621',
#  '14609',
#  '14621',
#  '14621',
#  '14613',
#  '14606',
#  '14608',
#  '14619',
#  '14613',
#  '14621',
#  '14621',
#  '14605',
#  '14605',
#  '14608',
#  '14611',
#  '14611',
#  '14605',
#  '14613',
#  '14606',
#  '14613',
#  '14613',
#  '14609',
#  '14621',
#  '14611',
#  '14605',
#  '14621',
#  '14609',
#  '14613',
#  '14608',
#  '14621',
#  '14605',
#  '14611',
#  '14609',
#  '14621',
#  '14621',
#  '14608',
#  '14621',
#  '14621',
#  '14613',
#  '14608',
#  '14608',
#  '14608',
#  '14609',
#  '14614',
#  '14614',
#  '14611',
#  '14611',
#  '14609',
#  '14609',
#  '14614',
#  '14609',
#  '14609',
#  '14611',
#  '14621',
#  '14604',
#  '14608',
#  '14608',
#  '14606',
#  '14613',
#  '14611',
#  '14621',
#  '14609',
#  '14615',
#  '14642',
#  '14619',
#  '14621',
#  '14621',
#  '14611',
#  '14608',
#  '14608',
#  '14606',
#  '14608',
#  '14608',
#  '14608',
#  '14608',
#  '14611',
#  '14609',
#  '14609',
#  '14606',
#  '14621',
#  '14621',
#  '14609',
#  '14611',
#  '14621',
#  '14605',
#  '14605',
#  '14621',
#  '14621',
#  '14605',
#  '14605',
#  '14608',
#  '14606',
#  '14621',
#  '14609',
#  '14605',
#  '14608',
#  '14615',
#  '14606',
#  '14621',
#  '14621',
#  '14619',
#  '14621',
#  '14611',
#  '14613',
#  '14606',
#  '14608',
#  '14621',
#  '14621',
#  '14621',
#  '14608',
#  '14613',
#  '14613',
#  '14613',
#  '14606',
#  '14621',
#  '14612',
#  '14611',
#  '14621',
#  '14611',
#  '14606',
#  '14604',
#  '14608']

# %%
gun_2022_23
# Out:
#              X          Y                                ID Case_Number  \
# 0   -77.610890  43.184163  7b9b3c9f85a442ce6a0aa2433ab8614f   22-109240
# 1   -77.598893  43.181793  82e3549d4dc8a835dea7130df2dcc851   22-106950
# 2   -77.630378  43.142970  bb9b98f90af42194e3a5b12a1ba8405f   22-106780
# 3   -77.580628  43.167216  dd0ab9214578b6e0d35467f6bb7b0fc3   22-106380
# 4   -77.641972  43.162394  5aac53d1517de031545f178e919c35b8   22-104298
# ..         ...        ...                               ...         ...
# 132 -77.594208  43.176265  170cc2716dcda68d990e13f160eb8e6d   22-002983
# 133 -77.653647  43.145521  8413049a1673e7652bc9a496b9822f8b   22-002302
# 134 -77.632012  43.160080  1cb272c96a18d27465d921e5df6df93a   22-002409
# 135 -77.603917  43.159877  11e489af1ae332d6ea0af7061c782115   22-001016
# 136 -77.626821  43.141037  1870a76a0d379ac9e58736f51974dbaf   22-000125
#
#               Address           Occurred_Date  Occurred_Month  Occurred_Year  \
# 0    442 Remington St  2022/06/01 04:00:00+00               6           2022
# 1      904 Hudson Ave  2022/05/29 04:00:00+00               5           2022
# 2     168 Bartlett St  2022/05/29 04:00:00+00               5           2022
# 3    720 N Goodman St  2022/05/28 04:00:00+00               5           2022
# 4       138 Murray St  2022/05/26 04:00:00+00               5           2022
# ..                ...                     ...             ...            ...
# 132   367 Alphonse St  2022/01/05 05:00:00+00               1           2022
# 133      211 Depew St  2022/01/04 05:00:00+00               1           2022
# 134     290 Saxton St  2022/01/04 05:00:00+00               1           2022
# 135      125 North St  2022/01/02 05:00:00+00               1           2022
# 136     204 Hawley St  2022/01/01 05:00:00+00               1           2022
#
#     Crime_Type Multiple_Shooting Gender   Race     Ethnicity  Victim_Age  \
# 0     Shooting                No      M  WHITE      HISPANIC          34
# 1     Homicide                No      M  WHITE      HISPANIC          42
# 2     Shooting                No      M  BLACK  NON HISPANIC          60
# 3     Shooting                No      M  BLACK  NON HISPANIC          28
# 4     Shooting                No      M  WHITE      HISPANIC          15
# ..         ...               ...    ...    ...           ...         ...
# 132   Shooting                No      M  BLACK  NON HISPANIC          45
# 133   Shooting                No      M  BLACK  NON HISPANIC          43
# 134   Shooting                No      M  BLACK  NON HISPANIC          15
# 135   Homicide                No      M  BLACK  NON HISPANIC          14
# 136   Shooting                No      M  BLACK  NON HISPANIC          30
#
#     Victim_Age_Band   Latitude  Longitude  ObjectId Zip_code
# 0             25-44  43.184163 -77.610890         1    14621
# 1             25-44  43.181793 -77.598893         2    14621
# 2          45-Older  43.142970 -77.630378         3    14611
# 3             25-44  43.167216 -77.580628         4    14609
# 4             15-24  43.162394 -77.641972         5    14606
# ..              ...        ...        ...       ...      ...
# 132        45-Older  43.176265 -77.594208       433    14621
# 133           25-44  43.145521 -77.653647       434    14611
# 134           15-24  43.160080 -77.632012       435    14606
# 135          14-May  43.159877 -77.603917       436    14604
# 136           25-44  43.141037 -77.626821       437    14608
#
# [137 rows x 19 columns]

# %%
gun_count = gun_2022_23.groupby(["Zip_code"])["X"].count().reset_index(name="count")

# %%
gun_count
# Out:
#    Zip_code  count
# 0     14604      2
# 1     14605     10
# 2     14606     11
# 3     14608     21
# 4     14609     19
# 5     14611     16
# 6     14612      1
# 7     14613     13
# 8     14614      3
# 9     14615      2
# 10    14619      4
# 11    14621     34
# 12    14642      1

# %%
import seaborn as sns
from fitter import Fitter, get_common_distributions, get_distributions

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 2)
sns.displot(data=roc_foodlink_data, x="Food Insecurity", kind="hist", bins = 100, aspect = 1.5)
